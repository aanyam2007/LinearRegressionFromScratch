# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('student_scores.csv')

# %%
plt.scatter(data.Hours,data.Scores)
plt.show()

# %%
from linear_regression import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from linear_regression import LinearRegression
#
# File ~\OneDrive\Desktop\LinearRegressionFromScratch\linear_regression.py:63
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "796441a7-7380-425d-a51d-d965f4800a7d",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import pandas as pd\n",
#      11     "import matplotlib.pyplot as plt"
#      12    ]
#      13   },
#      14   {
#      15    "cell_type": "code",
#      16    "execution_count": 2,
#      17    "id": "501e1e1a-09a5-405c-9ce8-2bcd2dada8b4",
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "import numpy as np"
#      22    ]
#      23   },
#      24   {
#      25    "cell_type": "code",
#      26    "execution_count": 5,
#      27    "id": "2afc996f-0f74-4a9f-aae2-e4112e360a68",
#      28    "metadata": {},
#      29    "outputs": [],
#      30    "source": [
#      31     "class LinearRegression:\n",
#      32     "    def __init__(self,lr=0.001,iter=1000):\n",
#      33     "        self.lr=lr\n",
#      34     "        self.iter=iter\n",
#      35     "        self.w=None\n",
#      36     "        self.b=None\n",
#      37     "\n",
#      38     "    def fit(self,x,y):\n",
#      39     "        samples,features=x.shape\n",
#      40     "\n",
#      41     "        # initialize parameters\n",
#      42     "        self.w=np.zeros(features)\n",
#      43     "        self.b=0\n",
#      44     "\n",
#      45     "        #gradient descent\n",
#      46     "        for i in range(self.iters):\n",
#      47     "            y_pred=np.dot(x, self.w)+self.b\n",
#      48     "\n",
#      49     "            # gradients\n",
#      50     "            dw=(1/samples)*np.dot(x.T,(y_pred-y))\n",
#      51     "            db=(1/samples)*np.sum(y_pred-y)\n",
#      52     "\n",
#      53     "            # update parameters\n",
#      54     "            self.w-=self.lr*dw\n",
#      55     "            self.b-=self.lr*db\n",
#      56     "\n",
#      57     "    def predict(self,x):\n",
#      58     "        return np.dot(x,self.w)+self.b"
#      59    ]
#      60   },
#      61   {
#      62    "cell_type": "code",
# ---> 63    "execution_count": null,
#      64    "id": "9bceafeb-167a-4a22-97f6-c8051f61980a",
#      65    "metadata": {},
#      66    "outputs": [],
#      67    "source": []
#      68   }
#      69  ],
#      70  "metadata": {
#      71   "kernelspec": {
#      72    "display_name": "Python 3 (ipykernel)",
#      73    "language": "python",
#      74    "name": "python3"
#      75   },
#      76   "language_info": {
#      77    "codemirror_mode": {
#      78     "name": "ipython",
#      79     "version": 3
#      80    },
#      81    "file_extension": ".py",
#      82    "mimetype": "text/x-python",
#      83    "name": "python",
#      84    "nbconvert_exporter": "python",
#      85    "pygments_lexer": "ipython3",
#      86    "version": "3.13.3"
#      87   }
#      88  },
#      89  "nbformat": 4,
#      90  "nbformat_minor": 5
#      91 }
#
# NameError: name 'null' is not defined

# %%
x=data.Hours
y=data.Scores

# %%
model=LinearRegression(lr=0.01, n_iters=1000)
model.fit(x, y)

# %%
y_pred=model.predict(X)

# %%
plt.scatter(x,y, color="blue",label="Data points")
plt.plot(x,y_pred,color="red",label="Regression line")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.legend()
plt.show()
